# %% [markdown]
# # House Data Lookup using Zillow API
#
# > In this project I am building upon the authors work. This will give estimated profit for a potential buyer to purchase the home as a rental property

# %% [markdown]
# Click [HERE](https://www.youtube.com/watch?v=o8Dfa3hUHtc) and [HERE](https://github.com/analyticsariel/projects/blob/master/property_data/zillow_property_data_api.ipynb) to see the references and templates I used for this work.

# %% [markdown]
# ### Import Packages

# %%
from googlesearch import search
import pandas as pd
import requests
import json
import time
import io
import plotly.express as px

# %%
# Set up Notebook

# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Run the Google Search for the URL of a property

# %%
# Create variable for search criteria / Address
# 7023 Calamar Drive Fayetteville NC 28314
property_address = "6520 Roaring Creek, Argyle TX 76226"
query = ' zillow homedetails' + property_address

# %%
# Create a list of the top 3 search results

results = search(query, num_results=3 )
results_list = [u for u in results] 
results_list
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\Python3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File C:\Python3\Lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File C:\Python3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File C:\Python3\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File C:\Python3\Lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File C:\Python3\Lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File C:\Python3\Lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#
# File C:\Python3\Lib\site-packages\urllib3\connection.py:179, in HTTPConnection._new_conn(self)
#     178 except SocketTimeout:
# --> 179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#     185 except SocketError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x0000028AAB89B410>, 'Connection to www.google.com timed out. (connect timeout=5)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File C:\Python3\Lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File C:\Python3\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File C:\Python3\Lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.google.com', port=443): Max retries exceeded with url: /search?q=%2Bzillow%2Bhomedetails6520%2BRoaring%2BCreek%2C%2BArgyle%2BTX%2B76226&num=5&hl=en&start=0 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000028AAB89B410>, 'Connection to www.google.com timed out. (connect timeout=5)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In [18], line 4
#       1 # Create a list of the top 3 search results
#       3 results = search(query, num_results=3 )
# ----> 4 results_list = [u for u in results]
#       5 results_list
#
# Cell In [18], line 4, in <listcomp>(.0)
#       1 # Create a list of the top 3 search results
#       3 results = search(query, num_results=3 )
# ----> 4 results_list = [u for u in results]
#       5 results_list
#
# File C:\Python3\Lib\site-packages\googlesearch\__init__.py:54, in search(term, num_results, lang, proxy, advanced, sleep_interval, timeout)
#      51 start = 0
#      52 while start < num_results:
#      53     # Send request
# ---> 54     resp = _req(escaped_term, num_results - start,
#      55                 lang, start, proxies, timeout)
#      57     # Parse
#      58     soup = BeautifulSoup(resp.text, "html.parser")
#
# File C:\Python3\Lib\site-packages\googlesearch\__init__.py:9, in _req(term, results, lang, start, proxies, timeout)
#       8 def _req(term, results, lang, start, proxies, timeout):
# ----> 9     resp = get(
#      10         url="https://www.google.com/search",
#      11         headers={
#      12             "User-Agent": get_useragent()
#      13         },
#      14         params={
#      15             "q": term,
#      16             "num": results + 2,  # Prevents multiple requests
#      17             "hl": lang,
#      18             "start": start,
#      19         },
#      20         proxies=proxies,
#      21         timeout=timeout,
#      22     )
#      23     resp.raise_for_status()
#      24     return resp
#
# File C:\Python3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File C:\Python3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File C:\Python3\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File C:\Python3\Lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File C:\Python3\Lib\site-packages\requests\adapters.py:553, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     550 if isinstance(e.reason, ConnectTimeoutError):
#     551     # TODO: Remove this in 3.0.0: see #2811
#     552     if not isinstance(e.reason, NewConnectionError):
# --> 553         raise ConnectTimeout(e, request=request)
#     555 if isinstance(e.reason, ResponseError):
#     556     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='www.google.com', port=443): Max retries exceeded with url: /search?q=%2Bzillow%2Bhomedetails6520%2BRoaring%2BCreek%2C%2BArgyle%2BTX%2B76226&num=5&hl=en&start=0 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000028AAB89B410>, 'Connection to www.google.com timed out. (connect timeout=5)'))

# %%
# Since "Zillow Home Details" is in the query it should be the number one result
url = results_list[0]
print(url)
# Out:
# https://www.zillow.com/homedetails/6512-Roaring-Crk-Argyle-TX-76226/243581467_zpid/

# %% [markdown]
# > The ZPID is what the Zillow API uses to find the data. The ZPID is the numeric part of the url ending with _zpid/

# %%
# Get the ZPID to search the property using the API
zpid = [x for x in url.split('/') if 'zpid' in x][0].split('_')[0]
print('Zpid of the property is:', zpid)
# Out:
# Zpid of the property is: 243581467

# %% [markdown]
# # Use API to get property details

# %%
# This code comes directly from rapidapi.com

url = "https://zillow-com1.p.rapidapi.com/property"

querystring = {"zpid":zpid}

headers = {
"X-RapidAPI-Key": "8246fc7aefmshce6cca477ba63adp1661d4jsn1f03c003e6b2",
"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

response.status_code
# 200 indicates successful request
# Out:
# 200

# %% [markdown]
# ### View Property Information

# %%
# Here is all of the data from the address listed

response.json()
# Out:
# {'listingProvider': {'enhancedVideoURL': None,
#   'showNoContactInfoMessage': False,
#   'postingGroupName': None,
#   'isZRMSourceText': None,
#   'showLogos': None,
#   'logos': {},
#   'sourceText': None,
#   'title': 'Listing Provided by',
#   'disclaimerText': None,
#   'postingWebsiteURL': None,
#   'agentLicenseNumber': None,
#   'postingWebsiteLinkText': 'See listing website',
#   'enhancedDescriptionText': None,
#   'agentName': None},
#  'zpid': 243581467,
#  'buildingPermits': None,
#  'propertyTaxRate': 1.77,
#  'contact_recipients': [{'agent_reason': 1,
#    'zpro': None,
#    'recent_sales': 2,
#    'review_count': 270,
#    'display_name': 'Swapnil Sharma',
#    'zuid': 'X1-ZUysm064vqjqx5_17jmc',
#    'rating_average': 4.9,
#    'badge_type': 'Premier Agent',
#    'phone': {'prefix': '225', 'areacode': '214', 'number': '3529'},
#    'image_url': 'https://photos.zillowstatic.com/h_n/IS72xokfxyoimw0000000000.jpg'}],
#  'zipcode': '76226',
#  'openHouseSchedule': {},
#  'longitude': -97.199196,
#  'zestimateLowPercent': '5',
#  'address': {'community': None,
#   'city': 'Argyle',
#   'state': 'TX',
#   'neighborhood': None,
#   'subdivision': None,
#   'streetAddress': '6512 Roaring Crk',
#   'zipcode': '76226'},
#  'cityId': 4351,
#  'timeOnZillow': None,
#  'url': '/homedetails/6512-Roaring-Crk-Argyle-TX-76226/243581467_zpid/',
#  'zestimate': 389300,
#  'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=400x300&zoom=17&center=33.13530349731445,-97.1991958618164&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&&signature=jbviwDFS0R9_3p_RoNFra7NmSdc=',
#  'description': 'This 1738 square foot single family home has 3 bedrooms and 2.0 bathrooms. This home is located at 6512 Roaring Crk, Argyle, TX 76226.',
#  'price': 389300,
#  'livingAreaValue': 1738,
#  'resoFacts': {'hasAttachedProperty': False,
#   'frontageType': None,
#   'poolFeatures': None,
#   'flooring': {},
#   'builderModel': None,
#   'accessibilityFeatures': None,
#   'hasGarage': False,
#   'hasPetsAllowed': None,
#   'bodyType': None,
#   'topography': None,
#   'landLeaseExpirationDate': None,
#   'hasAdditionalParcels': False,
#   'waterViewYN': None,
#   'livingQuarters': {},
#   'totalActualRent': None,
#   'offerReviewDate': None,
#   'horseYN': None,
#   'view': {},
#   'buyerAgencyCompensationType': None,
#   'rooms': {},
#   'belowGradeFinishedArea': None,
#   'feesAndDues': [{'phone': None,
#     'name': None,
#     'fee': '$44 monthly',
#     'type': 'HOA'}],
#   'cityRegion': 'Argyle',
#   'mainLevelBathrooms': None,
#   'hasPrivatePool': None,
#   'associationFeeIncludes': None,
#   'waterSource': None,
#   'carportParkingCapacity': None,
#   'inclusions': None,
#   'hasFireplace': True,
#   'gas': None,
#   'sewer': None,
#   'elevationUnits': None,
#   'roadSurfaceType': None,
#   'subdivisionName': None,
#   'numberOfUnitsVacant': None,
#   'hasWaterfrontView': None,
#   'bathroomsOneQuarter': None,
#   'lotSize': '5,889 sqft',
#   'entryLevel': None,
#   'irrigationWaterRightsAcres': None,
#   'greenWaterConservation': None,
#   'stories': None,
#   'bathrooms': 2,
#   'numberOfUnitsInCommunity': None,
#   'listingTerms': None,
#   'otherParking': None,
#   'associationFee': None,
#   'marketingType': None,
#   'greenIndoorAirQuality': None,
#   'greenSustainability': None,
#   'heating': ['Other'],
#   'associationPhone': None,
#   'greenBuildingVerificationType': None,
#   'hasAttachedGarage': None,
#   'bedrooms': 3,
#   'architecturalStyle': None,
#   'listingId': None,
#   'structureType': None,
#   'interiorFeatures': None,
#   'horseAmenities': None,
#   'electric': None,
#   'otherFacts': {},
#   'lotFeatures': None,
#   'roofType': 'Composition',
#   'constructionMaterials': {},
#   'fireplaceFeatures': None,
#   'hoaFeeTotal': '$44 monthly',
#   'doorFeatures': None,
#   'bathroomsPartial': None,
#   'bathroomsHalf': None,
#   'taxAnnualAmount': 6891,
#   'listAOR': None,
#   'buildingName': None,
#   'attic': None,
#   'mainLevelBedrooms': None,
#   'elementarySchool': None,
#   'virtualTour': None,
#   'hasCarport': None,
#   'canRaiseHorses': False,
#   'hasLandLease': False,
#   'communityFeatures': {},
#   'yearBuiltEffective': None,
#   'middleOrJuniorSchool': None,
#   'lotSizeDimensions': None,
#   'hasHomeWarranty': False,
#   'entryLocation': None,
#   'yearBuilt': 2017,
#   'propertySubType': None,
#   'propertyCondition': None,
#   'utilities': None,
#   'parcelNumber': 'R686335',
#   'incomeIncludes': None,
#   'highSchool': None,
#   'isNewConstruction': None,
#   'otherStructures': None,
#   'livingArea': '1,738 sqft',
#   'livingAreaRangeUnits': None,
#   'buildingArea': None,
#   'windowFeatures': None,
#   'ownership': None,
#   'woodedArea': None,
#   'middleOrJuniorSchoolDistrict': None,
#   'associationPhone2': None,
#   'isSeniorCommunity': None,
#   'foundationDetails': ['Slab'],
#   'frontageLength': None,
#   'exteriorFeatures': ['Brick'],
#   'associationAmenities': None,
#   'buildingFeatures': None,
#   'hasCooling': True,
#   'buildingAreaSource': None,
#   'parkingFeatures': ['Garage - Attached'],
#   'foundationArea': None,
#   'zoning': None,
#   'hoaFee': '$44 monthly',
#   'livingAreaRange': None,
#   'bathroomsFull': None,
#   'additionalParcelsDescription': None,
#   'waterBodyName': None,
#   'waterfrontFeatures': None,
#   'aboveGradeFinishedArea': None,
#   'zoningDescription': None,
#   'levels': None,
#   'basementYN': False,
#   'hasView': False,
#   'appliances': {},
#   'securityFeatures': None,
#   'elevation': None,
#   'fencing': None,
#   'greenEnergyEfficient': None,
#   'developmentStatus': None,
#   'ownershipType': None,
#   'garageParkingCapacity': None,
#   'associations': [{'feeFrequency': '$44 monthly',
#     'name': None,
#     'phone': None}],
#   'waterView': '',
#   'laundryFeatures': None,
#   'buyerAgencyCompensation': None,
#   'basement': None,
#   'additionalFeeInfo': None,
#   'commonWalls': None,
#   'homeType': 'SingleFamily',
#   'spaFeatures': None,
#   'municipality': None,
#   'bathroomsThreeQuarter': None,
#   'hasSpa': False,
#   'hasHeating': True,
#   'associationFee2': None,
#   'cooling': ['Central'],
#   'openParkingCapacity': None,
#   'associationName2': None,
#   'hasRentControl': None,
#   'elementarySchoolDistrict': None,
#   'otherEquipment': None,
#   'associationName': None,
#   'specialListingConditions': None,
#   'furnished': False,
#   'vegetation': None,
#   'patioAndPorchFeatures': None,
#   'bathroomsFloat': 2,
#   'builderName': None,
#   'highSchoolDistrict': None,
#   'exclusions': None,
#   'storiesTotal': None,
#   'landLeaseAmount': None,
#   'fireplaces': None,
#   'availabilityDate': None,
#   'cropsIncludedYN': None,
#   'coveredParkingCapacity': None,
#   'irrigationWaterRightsYN': None,
#   'hasOpenParking': None,
#   'onMarketDate': None,
#   'hasElectricOnProperty': None,
#   'parkingCapacity': 0,
#   'pricePerSquareFoot': 224,
#   'atAGlanceFacts': [{'factValue': 'SingleFamily', 'factLabel': 'Type'},
#    {'factValue': '2017', 'factLabel': 'Year Built'},
#    {'factValue': 'Other', 'factLabel': 'Heating'},
#    {'factValue': 'Central', 'factLabel': 'Cooling'},
#    {'factValue': 'Garage - Attached', 'factLabel': 'Parking'},
#    {'factValue': '$44 monthly', 'factLabel': 'HOA'},
#    {'factValue': '5,889 sqft', 'factLabel': 'Lot'},
#    {'factValue': None, 'factLabel': 'Offer Review Date'}],
#   'hasAssociation': True},
#  'taxHistory': [{'time': 1658434955737,
#    'valueIncreaseRate': 0.14645089,
#    'taxIncreaseRate': 0.12624638,
#    'taxPaid': 6601.82,
#    'value': 310992},
#   {'time': 1626898955737,
#    'valueIncreaseRate': 0.106431834,
#    'taxIncreaseRate': 0.07550847,
#    'taxPaid': 5861.79,
#    'value': 271265},
#   {'time': 1595362955737,
#    'valueIncreaseRate': -0.039313648,
#    'taxIncreaseRate': -0.06566285,
#    'taxPaid': 5450.25,
#    'value': 245171},
#   {'time': 1563740555737,
#    'valueIncreaseRate': 0.07347646,
#    'taxIncreaseRate': 0.028434377,
#    'taxPaid': 5833.28,
#    'value': 255204},
#   {'time': 1532204555737,
#    'valueIncreaseRate': 7.2555823,
#    'taxIncreaseRate': 0,
#    'taxPaid': 5672,
#    'value': 237736},
#   {'time': 1500668555737,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 28797}],
#  'brokerId': None,
#  'stateId': 54,
#  'streetAddress': '6512 Roaring Crk',
#  'listingSubType': {'is_FSBA': False,
#   'is_comingSoon': False,
#   'is_newHome': False,
#   'is_pending': False,
#   'is_forAuction': False,
#   'is_foreclosure': False,
#   'is_bankOwned': False,
#   'is_openHouse': False,
#   'is_FSBO': False},
#  'solarPotential': None,
#  'dateSold': None,
#  'countyId': None,
#  'timeZone': 'America/Chicago',
#  'homeType': 'SINGLE_FAMILY',
#  'livingAreaUnits': 'sqft',
#  'comingSoonOnMarketDate': None,
#  'rentZestimate': 2375,
#  'bathrooms': 2,
#  'annualHomeownersInsurance': 1635,
#  'state': 'TX',
#  'propertyTypeDimension': 'Single Family',
#  'building': None,
#  'listed_by': {'agent_reason': None,
#   'zpro': None,
#   'recent_sales': None,
#   'review_count': None,
#   'display_name': None,
#   'badge_type': None,
#   'business_name': None,
#   'rating_average': None,
#   'phone': None,
#   'zuid': None,
#   'image_url': None},
#  'yearBuilt': 2017,
#  'brokerageName': None,
#  'pageViewCount': None,
#  'county': 'Denton County',
#  'mortgageRates': {'thirtyYearFixedRate': 6.576},
#  'attributionInfo': {'buyerAgentName': None,
#   'mlsName': None,
#   'coAgentLicenseNumber': None,
#   'listingOffices': [{'associatedOfficeType': 'listOffice',
#     'officeName': None}],
#   'lastUpdated': None,
#   'buyerAgentMemberStateLicense': None,
#   'brokerName': None,
#   'listingAgreement': None,
#   'infoString10': None,
#   'trueStatus': None,
#   'infoString3': None,
#   'agentEmail': None,
#   'agentName': None,
#   'attributionTitle': None,
#   'mlsId': None,
#   'coAgentName': None,
#   'coAgentNumber': None,
#   'infoString5': None,
#   'listingAgents': {},
#   'agentPhoneNumber': None,
#   'agentLicenseNumber': None,
#   'providerLogo': None,
#   'infoString16': None,
#   'buyerBrokerageName': None,
#   'mlsDisclaimer': None,
#   'brokerPhoneNumber': None,
#   'lastChecked': None},
#  'monthlyHoaFee': 44,
#  'homeStatus': 'OTHER',
#  'homeFacts': None,
#  'latitude': 33.135303,
#  'datePosted': '',
#  'bedrooms': 3,
#  'nearbyHomes': [{'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/0412adfc818864ec41e9c7f260371871-p_c.jpg'}],
#    'zpid': 2092175661,
#    'longitude': -97.199326,
#    'address': {'city': 'Argyle',
#     'state': 'TX',
#     'streetAddress': '6516 Roaring Crk',
#     'zipcode': '76226'},
#    'price': 503900,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 33.135323},
#   {'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/a60998454751fd5cc68460d4ac5bc107-p_c.jpg'}],
#    'zpid': 243581454,
#    'longitude': -97.199036,
#    'address': {'city': 'Argyle',
#     'state': 'TX',
#     'streetAddress': '6508 Roaring Crk',
#     'zipcode': '76226'},
#    'price': 403400,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 33.1353},
#   {'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/234f793c5321cbec72e0c20c2baf4c8a-p_c.jpg'}],
#    'zpid': 243579991,
#    'longitude': -97.19936,
#    'address': {'city': 'Argyle',
#     'state': 'TX',
#     'streetAddress': '6516 Roaring Crk',
#     'zipcode': '76226'},
#    'price': 458000,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 33.135303},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=316x234&zoom=17&center=33.13520050048828,-97.19940185546875&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&&signature=ESzp6KblQkyaaZyzuy__gNeUAqw='}],
#    'zpid': 2092504139,
#    'longitude': -97.1994,
#    'address': {'city': 'Denton',
#     'state': 'TX',
#     'streetAddress': '6620 Roaring Creek Drive',
#     'zipcode': '76226'},
#    'price': 395100,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 33.1352},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=316x234&zoom=17&center=33.13529968261719,-97.19886779785156&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&&signature=673LZXns5H0n4kJuNtzuNV0bzv0='}],
#    'zpid': 243581490,
#    'longitude': -97.19887,
#    'address': {'city': 'Argyle',
#     'state': 'TX',
#     'streetAddress': '6504 Roaring Crk',
#     'zipcode': '76226'},
#    'price': 429200,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 33.1353},
#   {'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/a9191e0d1840e882db003d765de42fa6-p_c.jpg'}],
#    'zpid': 243579919,
#    'longitude': -97.199524,
#    'address': {'city': 'Argyle',
#     'state': 'TX',
#     'streetAddress': '6520 Roaring Crk',
#     'zipcode': '76226'},
#    'price': 0,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'RECENTLY_SOLD',
#    'currency': 'USD',
#    'latitude': 33.135303},
#   {'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/0a813a27bb8bafdd32bb33cae780c07a-p_c.jpg'}],
#    'zpid': 243579883,
#    'longitude': -97.19871,
#    'address': {'city': 'Argyle',
#     'state': 'TX',
#     'streetAddress': '6500 Roaring Crk',
#     'zipcode': '76226'},
#    'price': 526900,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 33.1353},
#   {'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/047ab3398bf66a2239d9aedf2bec1a0e-p_c.jpg'}],
#    'zpid': 243581669,
#    'longitude': -97.199684,
#    'address': {'city': 'Argyle',
#     'state': 'TX',
#     'streetAddress': '6600 Roaring Crk',
#     'zipcode': '76226'},
#    'price': 396300,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 33.135303}],
#  'livingArea': 1738,
#  'priceHistory': {},
#  'favoriteCount': None,
#  'schools': [{'link': 'https://www.greatschools.org/school?id=08940&state=TX',
#    'rating': 9,
#    'totalCount': None,
#    'distance': 4.1,
#    'assigned': None,
#    'name': 'Ryan Elementary School',
#    'studentsPerTeacher': None,
#    'isAssigned': None,
#    'size': None,
#    'level': 'Primary',
#    'grades': 'PK-5',
#    'type': 'Public'},
#   {'link': 'https://www.greatschools.org/school?id=02068&state=TX',
#    'rating': 6,
#    'totalCount': None,
#    'distance': 5.6,
#    'assigned': None,
#    'name': 'Mcmath Middle School',
#    'studentsPerTeacher': None,
#    'isAssigned': None,
#    'size': None,
#    'level': 'Middle',
#    'grades': '6-8',
#    'type': 'Public'},
#   {'link': 'https://www.greatschools.org/school?id=02049&state=TX',
#    'rating': 4,
#    'totalCount': None,
#    'distance': 7,
#    'assigned': None,
#    'name': 'Denton High School',
#    'studentsPerTeacher': None,
#    'isAssigned': None,
#    'size': None,
#    'level': 'High',
#    'grades': '9-12',
#    'type': 'Public'}],
#  'zestimateHighPercent': '5',
#  'mlsid': None,
#  'countyFIPS': '48121',
#  'city': 'Argyle',
#  'providerListingID': None,
#  'country': 'USA',
#  'currency': 'USD',
#  'isListedByOwner': None,
#  'contingentListingType': None}

# %% [markdown]
# ### Create Pandas DF

# %%
# transform data to pandas dataframe
df_property_detail = pd.json_normalize(data=response.json())
print('Num of rows:', len(df_property_detail))
print('Num of cols:', len(df_property_detail.columns))
df_property_detail.head()
# Out:
# Num of rows: 1
# Num of cols: 291
#         zpid buildingPermits  propertyTaxRate
# 0  243581467            None             1.77  \
#
#                                   contact_recipients zipcode  longitude
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal...   76226 -97.199196  \
#
#   zestimateLowPercent  cityId timeOnZillow
# 0                   5    4351         None  \
#
#                                                  url  zestimate
# 0  /homedetails/6512-Roaring-Crk-Argyle-TX-76226/...     389300  \
#
#                                               imgSrc
# 0  https://maps.googleapis.com/maps/api/staticmap...  \
#
#                                          description   price  livingAreaValue
# 0  This 1738 square foot single family home has 3...  389300             1738  \
#
#                                           taxHistory brokerId  stateId
# 0  [{'time': 1658434955737, 'valueIncreaseRate': ...     None       54  \
#
#       streetAddress solarPotential dateSold countyId         timeZone
# 0  6512 Roaring Crk           None     None     None  America/Chicago  \
#
#         homeType livingAreaUnits comingSoonOnMarketDate  rentZestimate
# 0  SINGLE_FAMILY            sqft                   None           2375  \
#
#    bathrooms  annualHomeownersInsurance state propertyTypeDimension building
# 0          2                       1635    TX         Single Family     None  \
#
#    yearBuilt brokerageName pageViewCount         county  monthlyHoaFee
# 0       2017          None          None  Denton County             44  \
#
#   homeStatus homeFacts   latitude datePosted  bedrooms
# 0      OTHER      None  33.135303                    3  \
#
#                                          nearbyHomes  livingArea
# 0  [{'miniCardPhotos': [{'url': 'https://photos.z...        1738  \
#
#   favoriteCount                                            schools
# 0          None  [{'link': 'https://www.greatschools.org/school...  \
#
#   zestimateHighPercent mlsid countyFIPS    city providerListingID country
# 0                    5  None      48121  Argyle              None     USA  \
#
#   currency isListedByOwner contingentListingType
# 0      USD            None                  None  \
#
#   listingProvider.enhancedVideoURL  listingProvider.showNoContactInfoMessage
# 0                             None                                     False  \
#
#   listingProvider.postingGroupName listingProvider.isZRMSourceText
# 0                             None                            None  \
#
#   listingProvider.showLogos listingProvider.sourceText listingProvider.title
# 0                      None                       None   Listing Provided by  \
#
#   listingProvider.disclaimerText listingProvider.postingWebsiteURL
# 0                           None                              None  \
#
#   listingProvider.agentLicenseNumber listingProvider.postingWebsiteLinkText
# 0                               None                    See listing website  \
#
#   listingProvider.enhancedDescriptionText listingProvider.agentName
# 0                                    None                      None  \
#
#   address.community address.city address.state address.neighborhood
# 0              None       Argyle            TX                 None  \
#
#   address.subdivision address.streetAddress address.zipcode
# 0                None      6512 Roaring Crk           76226  \
#
#    resoFacts.hasAttachedProperty resoFacts.frontageType
# 0                          False                   None  \
#
#   resoFacts.poolFeatures resoFacts.builderModel
# 0                   None                   None  \
#
#   resoFacts.accessibilityFeatures  resoFacts.hasGarage
# 0                            None                False  \
#
#   resoFacts.hasPetsAllowed resoFacts.bodyType resoFacts.topography
# 0                     None               None                 None  \
#
#   resoFacts.landLeaseExpirationDate  resoFacts.hasAdditionalParcels
# 0                              None                           False  \
#
#   resoFacts.waterViewYN resoFacts.totalActualRent resoFacts.offerReviewDate
# 0                  None                      None                      None  \
#
#   resoFacts.horseYN resoFacts.buyerAgencyCompensationType
# 0              None                                  None  \
#
#   resoFacts.belowGradeFinishedArea
# 0                             None  \
#
#                                resoFacts.feesAndDues resoFacts.cityRegion
# 0  [{'phone': None, 'name': None, 'fee': '$44 mon...               Argyle  \
#
#   resoFacts.mainLevelBathrooms resoFacts.hasPrivatePool
# 0                         None                     None  \
#
#   resoFacts.associationFeeIncludes resoFacts.waterSource
# 0                             None                  None  \
#
#   resoFacts.carportParkingCapacity resoFacts.inclusions
# 0                             None                 None  \
#
#    resoFacts.hasFireplace resoFacts.gas resoFacts.sewer
# 0                    True          None            None  \
#
#   resoFacts.elevationUnits resoFacts.roadSurfaceType
# 0                     None                      None  \
#
#   resoFacts.subdivisionName resoFacts.numberOfUnitsVacant
# 0                      None                          None  \
#
#   resoFacts.hasWaterfrontView resoFacts.bathroomsOneQuarter resoFacts.lotSize
# 0                        None                          None        5,889 sqft  \
#
#   resoFacts.entryLevel resoFacts.irrigationWaterRightsAcres
# 0                 None                                 None  \
#
#   resoFacts.greenWaterConservation resoFacts.stories  resoFacts.bathrooms
# 0                             None              None                    2  \
#
#   resoFacts.numberOfUnitsInCommunity resoFacts.listingTerms
# 0                               None                   None  \
#
#   resoFacts.otherParking resoFacts.associationFee resoFacts.marketingType
# 0                   None                     None                    None  \
#
#   resoFacts.greenIndoorAirQuality resoFacts.greenSustainability
# 0                            None                          None  \
#
#   resoFacts.heating resoFacts.associationPhone
# 0           [Other]                       None  \
#
#   resoFacts.greenBuildingVerificationType resoFacts.hasAttachedGarage
# 0                                    None                        None  \
#
#    resoFacts.bedrooms resoFacts.architecturalStyle resoFacts.listingId
# 0                   3                         None                None  \
#
#   resoFacts.structureType resoFacts.interiorFeatures resoFacts.horseAmenities
# 0                    None                       None                     None  \
#
#   resoFacts.electric resoFacts.lotFeatures resoFacts.roofType
# 0               None                  None        Composition  \
#
#   resoFacts.fireplaceFeatures resoFacts.hoaFeeTotal resoFacts.doorFeatures
# 0                        None           $44 monthly                   None  \
#
#   resoFacts.bathroomsPartial resoFacts.bathroomsHalf
# 0                       None                    None  \
#
#    resoFacts.taxAnnualAmount resoFacts.listAOR resoFacts.buildingName
# 0                       6891              None                   None  \
#
#   resoFacts.attic resoFacts.mainLevelBedrooms resoFacts.elementarySchool
# 0            None                        None                       None  \
#
#   resoFacts.virtualTour resoFacts.hasCarport  resoFacts.canRaiseHorses
# 0                  None                 None                     False  \
#
#    resoFacts.hasLandLease resoFacts.yearBuiltEffective
# 0                   False                         None  \
#
#   resoFacts.middleOrJuniorSchool resoFacts.lotSizeDimensions
# 0                           None                        None  \
#
#    resoFacts.hasHomeWarranty resoFacts.entryLocation  resoFacts.yearBuilt
# 0                      False                    None                 2017  \
#
#   resoFacts.propertySubType resoFacts.propertyCondition resoFacts.utilities
# 0                      None                        None                None  \
#
#   resoFacts.parcelNumber resoFacts.incomeIncludes resoFacts.highSchool
# 0                R686335                     None                 None  \
#
#   resoFacts.isNewConstruction resoFacts.otherStructures resoFacts.livingArea
# 0                        None                      None           1,738 sqft  \
#
#   resoFacts.livingAreaRangeUnits resoFacts.buildingArea
# 0                           None                   None  \
#
#   resoFacts.windowFeatures resoFacts.ownership resoFacts.woodedArea
# 0                     None                None                 None  \
#
#   resoFacts.middleOrJuniorSchoolDistrict resoFacts.associationPhone2
# 0                                   None                        None  \
#
#   resoFacts.isSeniorCommunity resoFacts.foundationDetails
# 0                        None                      [Slab]  \
#
#   resoFacts.frontageLength resoFacts.exteriorFeatures
# 0                     None                    [Brick]  \
#
#   resoFacts.associationAmenities resoFacts.buildingFeatures
# 0                           None                       None  \
#
#    resoFacts.hasCooling resoFacts.buildingAreaSource
# 0                  True                         None  \
#
#   resoFacts.parkingFeatures resoFacts.foundationArea resoFacts.zoning
# 0       [Garage - Attached]                     None             None  \
#
#   resoFacts.hoaFee resoFacts.livingAreaRange resoFacts.bathroomsFull
# 0      $44 monthly                      None                    None  \
#
#   resoFacts.additionalParcelsDescription resoFacts.waterBodyName
# 0                                   None                    None  \
#
#   resoFacts.waterfrontFeatures resoFacts.aboveGradeFinishedArea
# 0                         None                             None  \
#
#   resoFacts.zoningDescription resoFacts.levels  resoFacts.basementYN
# 0                        None             None                 False  \
#
#    resoFacts.hasView resoFacts.securityFeatures resoFacts.elevation
# 0              False                       None                None  \
#
#   resoFacts.fencing resoFacts.greenEnergyEfficient
# 0              None                           None  \
#
#   resoFacts.developmentStatus resoFacts.ownershipType
# 0                        None                    None  \
#
#   resoFacts.garageParkingCapacity
# 0                            None  \
#
#                               resoFacts.associations resoFacts.waterView
# 0  [{'feeFrequency': '$44 monthly', 'name': None,...                      \
#
#   resoFacts.laundryFeatures resoFacts.buyerAgencyCompensation
# 0                      None                              None  \
#
#   resoFacts.basement resoFacts.additionalFeeInfo resoFacts.commonWalls
# 0               None                        None                  None  \
#
#   resoFacts.homeType resoFacts.spaFeatures resoFacts.municipality
# 0       SingleFamily                  None                   None  \
#
#   resoFacts.bathroomsThreeQuarter  resoFacts.hasSpa  resoFacts.hasHeating
# 0                            None             False                  True  \
#
#   resoFacts.associationFee2 resoFacts.cooling resoFacts.openParkingCapacity
# 0                      None         [Central]                          None  \
#
#   resoFacts.associationName2 resoFacts.hasRentControl
# 0                       None                     None  \
#
#   resoFacts.elementarySchoolDistrict resoFacts.otherEquipment
# 0                               None                     None  \
#
#   resoFacts.associationName resoFacts.specialListingConditions
# 0                      None                               None  \
#
#    resoFacts.furnished resoFacts.vegetation resoFacts.patioAndPorchFeatures
# 0                False                 None                            None  \
#
#    resoFacts.bathroomsFloat resoFacts.builderName
# 0                         2                  None  \
#
#   resoFacts.highSchoolDistrict resoFacts.exclusions resoFacts.storiesTotal
# 0                         None                 None                   None  \
#
#   resoFacts.landLeaseAmount resoFacts.fireplaces resoFacts.availabilityDate
# 0                      None                 None                       None  \
#
#   resoFacts.cropsIncludedYN resoFacts.coveredParkingCapacity
# 0                      None                             None  \
#
#   resoFacts.irrigationWaterRightsYN resoFacts.hasOpenParking
# 0                              None                     None  \
#
#   resoFacts.onMarketDate resoFacts.hasElectricOnProperty
# 0                   None                            None  \
#
#    resoFacts.parkingCapacity  resoFacts.pricePerSquareFoot
# 0                          0                           224  \
#
#                             resoFacts.atAGlanceFacts
# 0  [{'factValue': 'SingleFamily', 'factLabel': 'T...  \
#
#    resoFacts.hasAssociation  listingSubType.is_FSBA
# 0                      True                   False  \
#
#    listingSubType.is_comingSoon  listingSubType.is_newHome
# 0                         False                      False  \
#
#    listingSubType.is_pending  listingSubType.is_forAuction
# 0                      False                         False  \
#
#    listingSubType.is_foreclosure  listingSubType.is_bankOwned
# 0                          False                        False  \
#
#    listingSubType.is_openHouse  listingSubType.is_FSBO listed_by.agent_reason
# 0                        False                   False                   None  \
#
#   listed_by.zpro listed_by.recent_sales listed_by.review_count
# 0           None                   None                   None  \
#
#   listed_by.display_name listed_by.badge_type listed_by.business_name
# 0                   None                 None                    None  \
#
#   listed_by.rating_average listed_by.phone listed_by.zuid listed_by.image_url
# 0                     None            None           None                None  \
#
#    mortgageRates.thirtyYearFixedRate attributionInfo.buyerAgentName
# 0                              6.576                           None  \
#
#   attributionInfo.mlsName attributionInfo.coAgentLicenseNumber
# 0                    None                                 None  \
#
#                       attributionInfo.listingOffices
# 0  [{'associatedOfficeType': 'listOffice', 'offic...  \
#
#   attributionInfo.lastUpdated attributionInfo.buyerAgentMemberStateLicense
# 0                        None                                         None  \
#
#   attributionInfo.brokerName attributionInfo.listingAgreement
# 0                       None                             None  \
#
#   attributionInfo.infoString10 attributionInfo.trueStatus
# 0                         None                       None  \
#
#   attributionInfo.infoString3 attributionInfo.agentEmail
# 0                        None                       None  \
#
#   attributionInfo.agentName attributionInfo.attributionTitle
# 0                      None                             None  \
#
#   attributionInfo.mlsId attributionInfo.coAgentName
# 0                  None                        None  \
#
#   attributionInfo.coAgentNumber attributionInfo.infoString5
# 0                          None                        None  \
#
#   attributionInfo.agentPhoneNumber attributionInfo.agentLicenseNumber
# 0                             None                               None  \
#
#   attributionInfo.providerLogo attributionInfo.infoString16
# 0                         None                         None  \
#
#   attributionInfo.buyerBrokerageName attributionInfo.mlsDisclaimer
# 0                               None                          None  \
#
#   attributionInfo.brokerPhoneNumber attributionInfo.lastChecked
# 0                              None                        None

# %% [markdown]
# ### Pull the most recent tax rate on the property

# %%
taxHistory = df_property_detail['taxHistory'].iloc[0]

# Sort the tax history by 'time' in descending order to get the most recent entry
sorted_taxHistory = sorted(taxHistory, key=lambda x: x['time'], reverse=True)

# Get the most recent taxPaid value
most_recent_taxPaid = sorted_taxHistory[0]['taxPaid']

print('Most recent taxPaid: {}'.format(most_recent_taxPaid))
# Out:
# Most recent taxPaid: 6601.82

# %% [markdown]
# # External Data for Inputs
# > Most Current Mortgage Rate

# %%
import requests
from bs4 import BeautifulSoup

# Send a GET request to the website that provides mortgage rates
response = requests.get('https://www.usbank.com/home-loans/mortgage/mortgage-rates.html')

# Assuming you have the HTML content in a variable named 'html_content'
html_content = '<span class="mortgageSingleRate conventional 30 display large">6.750%</span>'

# Create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find the element containing the mortgage rate
rate_element = soup.find('span', class_='mortgageSingleRate')

# Extract the rate from the element
rate = rate_element.text.strip()


numeric_rate = float(rate.strip('%'))
print('Mortgage rate (numeric): {:.4f}'.format(numeric_rate))
# Out:
# Mortgage rate (numeric): 6.7500

# %% [markdown]
# ## Property Details and Information

# %%
#               Property Information

# school lot_size = df_property_detail['resoFacts.lotSize'].iloc[0]
high_school_district = df_property_detail['resoFacts.highSchoolDistrict'].iloc[0]
mid_school_district = df_property_detail['resoFacts.middleOrJuniorSchoolDistrict'].iloc[0]
ele_school_district = df_property_detail['resoFacts.elementarySchoolDistrict'].iloc[0]

bedrooms = df_property_detail['bedrooms'].iloc[0]
bathrooms = df_property_detail['bathrooms'].iloc[0]
year_built = df_property_detail['yearBuilt'].iloc[0]
property_type = df_property_detail['homeType'].iloc[0]
living_area = df_property_detail['resoFacts.livingArea'].iloc[0]
lot_dimensions = df_property_detail['resoFacts.lotSizeDimensions'].iloc[0]
zoning = df_property_detail['resoFacts.zoning'].iloc[0]

# %% [markdown]
# ## Input Numbers

# %%
# Estimated Price
zestimate = df_property_detail['zestimate'].iloc[0]

# Estimated Down Payment
down_payment = zestimate * .4  # Can we make this an input

# Principal
principal = zestimate - down_payment

# Interest Rate
interest_rate = numeric_rate/100  # Annual interest rate  NEED to make this an input

# Loan Term
loan_term = 30  # Loan term in years NEED to make this an Input

##  Now the rent zestimate 
rent_zestimate = df_property_detail['rentZestimate'].iloc[0]

# %%
zestimate
# Out:
# 389300

# %% [markdown]
# ## Payment Calculations

# %%
# Mortgage Payment Calculation

monthly_interest_rate = interest_rate / 12  # Monthly interest rate
num_payments = loan_term * 12  # Total number of payments

##  Calculate the monthly mortgage payment
monthly_payment = (principal * monthly_interest_rate) / (1 - (1 + monthly_interest_rate) ** -num_payments)

## Other Expenses

# Insurance   
annual_insurance = df_property_detail['annualHomeownersInsurance'].iloc[0]
insurance = annual_insurance / 12

# Taxes
monthly_taxes= most_recent_taxPaid / 12

# Prop Management
property_managment = rent_zestimate * .10

# Maintenance
maintencance_reserves = rent_zestimate * .03

# Vacancy 
vacancy_reserves = rent_zestimate * .03

# HOA
monthly_HOA = df_property_detail['monthlyHoaFee'].iloc[0]

## Total Expenses
total_expenses = monthly_payment + insurance + monthly_taxes + property_managment + maintencance_reserves + vacancy_reserves



####       Monthly Income 
monthly_income = rent_zestimate - total_expenses

## Annual Income
annual_income = monthly_income * 12

# %%
print('Rental Income Calculation For: ', property_address)
print('------------------------------------------------------------------')


print('Price: ${:,.0f}'.format(zestimate))
print('Down payment: ${:,.0f}'.format(down_payment))
print('Todays average 30 year rate: {:.2%}'.format(interest_rate))
# print('The payment will be: ${:,.0f}'.format(monthly_payment))

print('The estimated rent is: ${:,.0f}'.format(rent_zestimate))
print('The estimated expenses: ${:,.0f}'.format(total_expenses))


print('\tMortgage payment: ${:,.0f}'.format(monthly_payment)) # Mortgage

if insurance == 0:
    print("\tInsurance rate: Not Available")
else:
    print('\tInsurance: ${:,.0f}'.format(insurance)) # Insurance


print('\tMonthly Taxes: ${:,.0f}'.format(monthly_taxes))# Taxes
print('\tProperty Management: ${:,.0f}'.format(property_managment))# Prop Management
print('\tMaintenance: ${:,.0f}'.format(maintencance_reserves))# Maintenance
print('\tVacancy: ${:,.0f}'.format(vacancy_reserves))# Vacancy


# print('\tMonthly HOA: ${:,.0f}'.format(monthly_HOA))# HOA
if monthly_HOA not in [0, 15000]:
    print("\tHOA Fee N/A")
else:
    print('\tMonthly HOA: ${:,.0f}'.format(monthly_HOA)) # 
    

print('The estimated monthly income: ${:,.0f}'.format(monthly_income))

print('Estimated Annual Income: ${:,.0f}'.format(annual_income))



print("\n") 
print("\n") 
print("\n") 
print("\n") 


print('PROPERTY DETAILS FOR: ', property_address)
print('------------------------------------------------------------------')

print('  High School District: {}'.format( high_school_district))
print('  Middle School District: {}'.format( mid_school_district))
print('  Elementary School District: {}'.format( ele_school_district))

print('  Bedrooms: {}'.format( bedrooms))
print('  Bathrooms: {}'.format( bathrooms))
print('  Year Built: {}'.format( year_built))
print('  Living Area: {}'.format( living_area))
# print('  Lot Size: {}'.format( lot_size))
print('  Lot Dimensions: {}'.format( lot_dimensions))
print('  Zoning: {}'.format( zoning))
print('  Property Type: {}'.format( property_type))
print('  Zestimate: ${:,.0f}'.format( zestimate))
print('  Rent Zestimate: ${:,.0f}'.format( rent_zestimate))
# Out:
# Rental Income Calculation For:  6520 Roaring Creek Argyle TX 76226
# ------------------------------------------------------------------
# Price: $389,300
# Down payment: $155,720
# Todays average 30 year rate: 6.75%
# The estimated rent is: $2,375
# The estimated expenses: $2,581
# 	Mortgage payment: $1,515
# 	Insurance: $136
# 	Monthly Taxes: $550
# 	Property Management: $238
# 	Maintenance: $71
# 	Vacancy: $71
# 	HOA Fee N/A
# The estimated monthly income: $-206
# Estimated Annual Income: $-2,477
#
#
#
#
#
#
#
#
# PROPERTY DETAILS FOR:  6520 Roaring Creek Argyle TX 76226
# ------------------------------------------------------------------
#   High School District: None
#   Middle School District: None
#   Elementary School District: None
#   Bedrooms: 3
#   Bathrooms: 2
#   Year Built: 2017
#   Living Area: 1,738 sqft
#   Lot Dimensions: None
#   Zoning: None
#   Property Type: SINGLE_FAMILY
#   Zestimate: $389,300
#   Rent Zestimate: $2,375
